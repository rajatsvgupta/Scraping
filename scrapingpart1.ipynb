# %%
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
import lxml

# %%
result=requests.get("http://www.example.com/") #getting webpage through request

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
soup=bs(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Example Domain
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <style type="text/css">
#    body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#   </style>
#  </head>
# ...

# %%
a=soup.title

# %%
b=soup.select("title")

# %%
a
# Out:
# <title>Example Domain</title>

# %%
b
# Out:
# [<title>Example Domain</title>]

# %%
a.text
# Out:
# 'Example Domain'

# %%
b[0].text
# Out:
# 'Example Domain'

# %%
b[0].getText()
# Out:
# 'Example Domain'

# %%
c=soup.select("p")

# %%
c
# Out:
# [<p>This domain is for use in illustrative examples in documents. You may use this
#      domain in literature without prior coordination or asking for permission.</p>,
#  <p><a href="https://www.iana.org/domains/example">More information...</a></p>]

# %%
c[0].getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
c[0].text
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
d=soup.p

# %%
d.getText()
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %%
d.text
# Out:
# 'This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.'

# %% [markdown]
# 2nd part searching class

# %%
result=requests.get("https://en.wikipedia.org/wiki/FC_Bayern_Munich")

# %%
result
# Out:
# <Response [200]>

# %%
soup=bs(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>FC Bayern Munich - Wikipedia</title>
# ...

# %%
x=soup.select(".toctext")

# %%
x
# Out:
# [<span class="toctext">History</span>,
#  <span class="toctext">Early years (1900–1965)</span>,
#  <span class="toctext">The golden years (1965–1979)</span>,
#  <span class="toctext">From FC Breitnigge to FC Hollywood (1979–1998)</span>,
#  <span class="toctext">Renewed international success (1998–2007)</span>,
#  <span class="toctext">Robbery – Robben and Ribery (2007–2019)</span>,
#  <span class="toctext">Flick era (2019–present)</span>,
#  <span class="toctext">Kits</span>,
#  <span class="toctext">Kit suppliers and shirt sponsors</span>,
#  <span class="toctext">Kit deals</span>,
#  <span class="toctext">Crest</span>,
#  <span class="toctext">Stadiums</span>,
#  <span class="toctext">Supporters</span>,
#  <span class="toctext">Rivalries</span>,
#  <span class="toctext">Organization and finance</span>,
#  <span class="toctext">Social engagement and charity</span>,
#  <span class="toctext">Training facility</span>,
#  <span class="toctext">Honours</span>,
# ...

# %%
for y in x:
    print(y.text)
# Out:
# History
# Early years (1900–1965)
# The golden years (1965–1979)
# From FC Breitnigge to FC Hollywood (1979–1998)
# Renewed international success (1998–2007)
# Robbery – Robben and Ribery (2007–2019)
# Flick era (2019–present)
# Kits
# Kit suppliers and shirt sponsors
# Kit deals
# Crest
# Stadiums
# Supporters
# Rivalries
# Organization and finance
# Social engagement and charity
# Training facility
# Honours
# Domestic
# European
# Worldwide
# Trebles
# Players
# Squad
# Reserves and academy
# Out on loan
# Notable past players
# Captains
# Retired numbers
# Coaches
# Current staff
# Coaches since 1963
# Current board
# Other departments
# Football
# Reserve team
# Junior teams
# Women's team
# Senior football
# AllStars
# Other sports
# Basketball
# Bowling
# Chess
# Handball
# Referees
# Table tennis
# Defunct
# Baseball
# Ice hockey
# Gymnastics
# Literature
# Notes
# References
# External links

# %%
for y in x:
    print(y.getText())
# Out:
# History
# Early years (1900–1965)
# The golden years (1965–1979)
# From FC Breitnigge to FC Hollywood (1979–1998)
# Renewed international success (1998–2007)
# Robbery – Robben and Ribery (2007–2019)
# Flick era (2019–present)
# Kits
# Kit suppliers and shirt sponsors
# Kit deals
# Crest
# Stadiums
# Supporters
# Rivalries
# Organization and finance
# Social engagement and charity
# Training facility
# Honours
# Domestic
# European
# Worldwide
# Trebles
# Players
# Squad
# Reserves and academy
# Out on loan
# Notable past players
# Captains
# Retired numbers
# Coaches
# Current staff
# Coaches since 1963
# Current board
# Other departments
# Football
# Reserve team
# Junior teams
# Women's team
# Senior football
# AllStars
# Other sports
# Basketball
# Bowling
# Chess
# Handball
# Referees
# Table tennis
# Defunct
# Baseball
# Ice hockey
# Gymnastics
# Literature
# Notes
# References
# External links

# %% [markdown]
# grabbing an image

# %%
c=soup.select("img")

# %%
t=soup.select("img")

# %%
t[0]
# Out:
# <img alt="This is a good article. Click here for more information." data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/>

# %%
link=t[0]["src"]

# %%
link
# Out:
# '//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png'

# %%
#this is used for down image
#<img src='//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png'>

# %% [markdown]
# <img src='//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png'>

# %%
thumb_img=soup.select(".thumbimage")

# %%
thumb_img[0]
# Out:
# <img alt="" class="thumbimage" data-file-height="232" data-file-width="420" decoding="async" height="122" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/220px-Fcn-fcb1901.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/330px-Fcn-fcb1901.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/4/42/Fcn-fcb1901.jpg 2x" width="220"/>

# %%
thumb_img[0]["src"]
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/220px-Fcn-fcb1901.jpg'

# %% [markdown]
# <img src='//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/220px-Fcn-fcb1901.jpg'>

# %%
type(thumb_img)
# Out:
# list

# %%
type(thumb_img[0])
# Out:
# bs4.element.Tag

# %%
z=thumb_img[0]

# %%
z["class"]
# Out:
# ['thumbimage']

# %%
z["src"]
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/220px-Fcn-fcb1901.jpg'

# %%
j=z["src"]

# %%
img_link=requests.get(f"https:{j}")
print(img_link)
img_link.content
# Out:
# <Response [200]>
# ...

# %%
img_link=requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/4/42/Fcn-fcb1901.jpg/220px-Fcn-fcb1901.jpg")

# %%
img_link
# Out:
# <Response [200]>

# %%
img_link.content
# Out:
# b'\xff\xd8\xff\xdb\x00C\x00\x04\x03\x03\x04\x03\x03\x04\x04\x03\x04\x05\x04\x04\x05\x06\n\x07\x06\x06\x06\x06\r\t\n\x08\n\x0f\r\x10\x10\x0f\r\x0f\x0e\x11\x13\x18\x14\x11\x12\x17\x12\x0e\x0f\x15\x1c\x15\x17\x19\x19\x1b\x1b\x1b\x10\x14\x1d\x1f\x1d\x1a\x1f\x18\x1a\x1b\x1a\xff\xdb\x00Cz\x00\xdc\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x01\x05\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x05\x02\x03\x04\x06\x07\x08\x01\x00\t\xff\xc4\x00:\x10\x00\x02\x01\x03\x03\x03\x02\x05\x02\x04\x05\x04\x03\x01\x01\x00\x01\x02\x03\x04\x05\x11\x00\x12!\x06\x131"A\x07\x142Qaq\x81\x08#\x91\xa1\x15B\xb1\xc1\xd1\x16$b\xe1CR\xf0\x173\xff\xc4\x00\x16\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00
# ...

# %%
f=open("trial_with_img.jpg", "wb")
f.write(img_link.content)
# Out:
# 10332

# %%
f.close()

# %%
type(t[0])
# Out:
# bs4.element.Tag

# %%
#for all img on wikipedia page
""""
t=soup.select("img")
for i in range(len(soup.select("img"))):
    v=t[i]["src"]
    img_link=requests.get(f"https:{v}")
    f=open(f"first_part{i}.jpg","wb")
    f.write(img_link.content)
    f.close()
    
    """
# Out:
# '"\nt=soup.select("img")\nfor i in range(len(soup.select("img"))):\n    v=t[i]["src"]\n    img_link=requests.get(f"https:{v}")\n    f=open(f"first_part{i}.jpg","wb")\n    f.write(img_link.content)\n    f.close()\n    \n    '
